# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivanrenzmond-solidos/CPE310-IE22S1/blob/main/Getting_Started_With_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Activity No. <n> Hands-on Activity 6.2 Getting Started with Pandas**
# **Name:** Ivan Renzmond Castulo
#
# **Course Code:** CPE-310
#
# **Program**:BSIE
#
# **Course Title:** Fundamentals of Data Science
#
# **Date Performed:** 2/12/2026
#
# **Section:** IE22S1
#
# **Date Submitted:** 2/12/2026
#
# **Instructor:** Engr.Jimlord Quejado

# %% [markdown]
# # Section 1: Getting Started With Pandas
#
# We will begin by introducing the `Series`, `DataFrame`, and `Index` classes, which are the basic building blocks of the pandas library, and showing how to work with them. By the end of this section, you will be able to create DataFrames and perform operations on them to inspect and filter the data.

# %% [markdown]
# ## Anatomy of a DataFrame
#
# A **DataFrame** is composed of one or more **Series**. The names of the **Series** form the column names, and the row labels form the **Index**.

# %%
import pandas as pd

meteorites = pd.read_csv('/content/2019_Yellow_Taxi_Trip_Data (2).csv', nrows=5)

# %% [markdown]
# *Source: [NASA's Open Data Portal](https://data.nasa.gov/Space-Science/Meteorite-Landings/gh4g-9sfh)*

# %%
taxi
# Out:
#       vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0            2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1            1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2            2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3            2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4            2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
# ...        ...                      ...                      ...
# 9995         1  2019-10-23T17:39:59.000  2019-10-23T17:49:26.000
# 9996         1  2019-10-23T17:53:02.000  2019-10-23T18:00:45.000
# 9997         1  2019-10-23T17:07:16.000  2019-10-23T17:11:35.000
# 9998         1  2019-10-23T17:38:26.000  2019-10-23T17:49:28.000
# 9999         1  2019-10-23T17:22:14.000  2019-10-23T17:52:09.000
#
#       passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                   1           7.93           1                  N
# ...

# %% [markdown]
# #### Series:

# %%
taxi.vendorid
# Out:
# 0       2
# 1       1
# 2       2
# 3       2
# 4       2
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: vendorid, Length: 10000, dtype: int64

# %% [markdown]
# #### Columns:

# %%
taxi.columns #attribute NOT a function, ()
# Out:
# Index(['vendorid', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'ratecodeid', 'store_and_fwd_flag',
#        'pulocationid', 'dolocationid', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge'],
#       dtype='object')

# %% [markdown]
# #### Index:

# %%
taxi.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
sampleList = ['apple', 'orange', 'kiwi']

# %%
sampleList[-1]
# Out:
# 'kiwi'

# %% [markdown]
# ## Creating DataFrames
#
# We can create DataFrames from a variety of sources such as other Python objects, flat files, webscraping, and API requests. Here, we will see just a couple of examples, but be sure to check out [this page](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html) in the documentation for a complete list.

# %% [markdown]
# ### Using a flat file

# %%
import pandas as pd

taxi = pd.read_csv('/content/2019_Yellow_Taxi_Trip_Data (2).csv')

# %% [markdown]
# *Tip: There are many parameters to this function to handle some initial processing while reading in the file &ndash; be sure check out the [documentation](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html).*

# %% [markdown]
# ### Using data from an API
#
# Collect the data from [NASA's Open Data Portal](https://data.nasa.gov/Space-Science/Meteorite-Landings/gh4g-9sfh) using the Socrata Open Data API (SODA) with the `requests` library:

# %%
import requests

response = requests.get(
    'https://data.nasa.gov/resource/gh4g-9sfh.json',
    params={'$limit': 50_000}
)

if response.ok:
    payload = response.json()
else:
    print(f'Request was not successful and returned code: {response.status_code}.')
    payload = None
# Out:
# Request was not successful and returned code: 404.

# %% [markdown]
# Create the DataFrame with the resulting payload:

# %%
import pandas as pd

df = pd.DataFrame(payload)
df.head(3)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# *Tip: `df.to_csv('data.csv')` writes this data to a new file called `data.csv`.*

# %% [markdown]
# ## Inspecting the data
# Now that we have some data, we need to perform an initial inspection of it. This gives us information on what the data looks like, how many rows/columns there are, and how much data we have.

# %% [markdown]
# Let's inspect the `meteorites` data.

# %% [markdown]
# #### How many rows and columns are there?

# %%
taxi. vendorid
# Out:
# 0       2
# 1       1
# 2       2
# 3       2
# 4       2
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: vendorid, Length: 10000, dtype: int64

# %% [markdown]
# #### What are the column names?

# %%
taxi.columns
# Out:
# Index(['vendorid', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'ratecodeid', 'store_and_fwd_flag',
#        'pulocationid', 'dolocationid', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge'],
#       dtype='object')

# %% [markdown]
# #### What type of data does each column currently hold?

# %%
taxi.dtypes
# Out:
# vendorid                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# trip_distance            float64
# ratecodeid                 int64
# store_and_fwd_flag        object
# pulocationid               int64
# dolocationid               int64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# dtype: object

# %% [markdown]
# #### What does the data look like?

# %%
taxi.head(55)
# Out:
#     vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0          2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1          1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2          2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3          2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4          2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
# 5          2  2019-10-23T16:31:12.000  2019-10-23T16:43:20.000
# 6          2  2019-10-23T16:47:10.000  2019-10-23T16:53:17.000
# 7          2  2019-10-23T16:57:35.000  2019-10-23T17:21:28.000
# 8          1  2019-10-23T16:11:36.000  2019-10-23T16:19:33.000
# 9          1  2019-10-23T16:21:48.000  2019-10-23T16:30:04.000
# 10         1  2019-10-23T16:35:02.000  2019-10-23T17:57:38.000
# 11         1  2019-10-23T16:17:33.000  2019-10-23T16:32:58.000
# 12         1  2019-10-23T16:35:45.000  2019-10-23T16:39:14.000
# 13         2  2019-10-23T16:34:52.000  2019-10-23T16:47:38.000
# ...

# %% [markdown]
# Sometimes there may be extraneous data at the end of the file, so checking the bottom few rows is also important:

# %%
taxi.tail(30)
# Out:
#       vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 9970         2  2019-10-23T17:22:40.000  2019-10-23T17:40:48.000
# 9971         1  2019-10-23T17:29:31.000  2019-10-23T17:37:51.000
# 9972         1  2019-10-23T17:49:43.000  2019-10-23T18:00:34.000
# 9973         1  2019-10-23T17:02:32.000  2019-10-23T17:14:34.000
# 9974         1  2019-10-23T17:18:38.000  2019-10-23T17:36:29.000
# 9975         1  2019-10-23T17:32:43.000  2019-10-23T17:54:15.000
# 9976         2  2019-10-23T17:59:03.000  2019-10-23T18:54:03.000
# 9977         2  2019-10-23T16:03:31.000  2019-10-23T16:04:03.000
# 9978         2  2019-10-23T17:50:42.000  2019-10-23T18:56:35.000
# 9979         1  2019-10-23T17:53:07.000  2019-10-23T18:00:38.000
# 9980         2  2019-10-23T17:46:40.000  2019-10-23T18:05:47.000
# 9981         2  2019-10-23T17:21:50.000  2019-10-23T17:32:06.000
# 9982         2  2019-10-23T17:40:28.000  2019-10-23T18:04:53.000
# ...

# %% [markdown]
# #### Get some information about the DataFrame

# %%
taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   vendorid               10000 non-null  int64
#  1   tpep_pickup_datetime   10000 non-null  object
#  2   tpep_dropoff_datetime  10000 non-null  object
#  3   passenger_count        10000 non-null  int64
#  4   trip_distance          10000 non-null  float64
#  5   ratecodeid             10000 non-null  int64
#  6   store_and_fwd_flag     10000 non-null  object
#  7   pulocationid           10000 non-null  int64
#  8   dolocationid           10000 non-null  int64
#  9   payment_type           10000 non-null  int64
#  10  fare_amount            10000 non-null  float64
#  11  extra                  10000 non-null  float64
#  12  mta_tax                10000 non-null  float64
#  13  tip_amount             10000 non-null  float64
# ...

# %% [markdown]
# ## Extracting subsets
#
# A crucial part of working with DataFrames is extracting subsets of the data: finding rows that meet a certain set of criteria, isolating columns/rows of interest, etc. After narrowing down our data, we are closer to discovering insights. This section will be the backbone of many analysis tasks.

# %% [markdown]
# #### Selecting columns
#
# We can select columns as attributes if their names would be valid Python variables:

# %%
names = taxi.vendorid

# %%
names # Created a subset
# Out:
# 0            Aachen
# 1            Aarhus
# 2              Abee
# 3          Acapulco
# 4           Achiras
#             ...
# 45711    Zillah 002
# 45712        Zinder
# 45713          Zlin
# 45714     Zubkovsky
# 45715    Zulu Queen
# Name: name, Length: 45716, dtype: object

# %% [markdown]
# If they aren't, we have to select them as keys. However, we can select multiple columns at once this way:

# %%
taxi
# Out:
#       vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0            2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1            1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2            2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3            2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4            2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
# ...        ...                      ...                      ...
# 9995         1  2019-10-23T17:39:59.000  2019-10-23T17:49:26.000
# 9996         1  2019-10-23T17:53:02.000  2019-10-23T18:00:45.000
# 9997         1  2019-10-23T17:07:16.000  2019-10-23T17:11:35.000
# 9998         1  2019-10-23T17:38:26.000  2019-10-23T17:49:28.000
# 9999         1  2019-10-23T17:22:14.000  2019-10-23T17:52:09.000
#
#       passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                   1           7.93           1                  N
# ...

# %% [markdown]
# #### Selecting rows

# %%
taxi[100:114:2]
# Out:
#      vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 100         2  2019-10-23T16:00:07.000  2019-10-23T16:04:19.000
# 102         2  2019-10-23T16:08:49.000  2019-10-23T16:31:17.000
# 104         1  2019-10-23T16:43:12.000  2019-10-23T17:25:28.000
# 106         2  2019-10-23T16:40:11.000  2019-10-23T16:57:45.000
# 108         2  2019-10-23T16:26:40.000  2019-10-23T16:53:52.000
# 110         2  2019-10-23T16:16:13.000  2019-10-23T16:18:51.000
# 112         2  2019-10-23T16:32:36.000  2019-10-23T16:45:29.000
#
#      passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 100                2           0.69           1                  N
# 102                2           5.33           1                  N
# 104                1           7.30           1                  N
# 106                3           2.04           1                  N
# 108                1           3.21           1                  N
# ...

# %% [markdown]
# #### Indexing
#
# We use `iloc[]` to select rows and columns by their position:

# %%
taxi.iloc[0:20, 2:5]
# Out:
#       tpep_dropoff_datetime  passenger_count  trip_distance
# 0   2019-10-23T17:14:10.000                1           7.93
# 1   2019-10-23T16:45:26.000                1           2.00
# 2   2019-10-23T16:21:11.000                1           1.36
# 3   2019-10-23T16:43:26.000                1           1.00
# 4   2019-10-23T16:58:49.000                1           1.96
# 5   2019-10-23T16:43:20.000                1           1.62
# 6   2019-10-23T16:53:17.000                1           0.85
# 7   2019-10-23T17:21:28.000                1           4.70
# 8   2019-10-23T16:19:33.000                1           0.80
# 9   2019-10-23T16:30:04.000                2           0.60
# 10  2019-10-23T17:57:38.000                2          18.20
# 11  2019-10-23T16:32:58.000                1           2.10
# 12  2019-10-23T16:39:14.000                1           0.70
# 13  2019-10-23T16:47:38.000                1           2.86
# 14  2019-10-23T16:59:20.000                2           1.32
# ...

# %% [markdown]
# We use `loc[]` to select by name:

# %%
taxi.loc[100:104, ]
# Out:
#      vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 100         2  2019-10-23T16:00:07.000  2019-10-23T16:04:19.000
# 101         2  2019-10-23T16:08:07.000  2019-10-23T16:17:19.000
# 102         2  2019-10-23T16:08:49.000  2019-10-23T16:31:17.000
# 103         1  2019-10-23T16:15:37.000  2019-10-23T16:38:39.000
# 104         1  2019-10-23T16:43:12.000  2019-10-23T17:25:28.000
#
#      passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 100                2           0.69           1                  N
# 101                3           1.19           1                  N
# 102                2           5.33           1                  N
# 103                1           2.00           1                  N
# 104                1           7.30           1                  N
#
#      pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 100           148            79             2          5.0    1.0      0.5
# ...

# %% [markdown]
# #### Filtering with Boolean masks
#
# A **Boolean mask** is a array-like structure of Boolean values &ndash; it's a way to specify which rows/columns we want to select (`True`) and which we don't (`False`).

# %% [markdown]
# Here's an example of a Boolean mask for meteorites weighing more than 50 grams that were found on Earth (i.e., they were not observed falling):

# %%
(taxi > 50) & (taxi).fall == 'Found'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3223646435.py in <cell line: 0>()
# ----> 1 (taxi > 50) & (taxi).fall == 'Found'
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _cmp_method(self, other, op)
#    7898
#    7899         # See GH#4537 for discussion of scalar op behavior
# ...

# %% [markdown]
# **Important**: Take note of the syntax here. We surround each condition with parentheses, and we use bitwise operators (`&`, `|`, `~`) instead of logical operators (`and`, `or`, `not`).

# %% [markdown]
# We can use a Boolean mask to select the subset of meteorites weighing more than 1 million grams (1,000 kilograms or roughly 2,205 pounds) that were observed falling:

# %%
taxi[(taxi > 1e6) & (taxi.fall == 'Fell')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-13824025.py in <cell line: 0>()
# ----> 1 taxi[(taxi > 1e6) & (taxi.fall == 'Fell')]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _cmp_method(self, other, op)
#    7898
#    7899         # See GH#4537 for discussion of scalar op behavior
# ...

# %% [markdown]
# *Tip: Boolean masks can be used with `loc[]` and `iloc[]`.*

# %% [markdown]
# An alternative to this is the `query()` method:

# %%
taxi.query("`mass (g)` > 1e6 and fall == 'Fell'")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     230             if self.has_resolvers:
# --> 231                 return self.resolvers[key]
#     232
#
# /usr/lib/python3.12/collections/__init__.py in __getitem__(self, key)
#    1014                 pass
# -> 1015         return self.__missing__(key)            # support subclasses that define __missing__
#    1016
#
# /usr/lib/python3.12/collections/__init__.py in __missing__(self, key)
#    1006     def __missing__(self, key):
# -> 1007         raise KeyError(key)
#    1008
#
# KeyError: 'BACKTICK_QUOTED_STRING_mass__LPAR_g_RPAR_'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# *Tip: Here, we can use both logical operators and bitwise operators.*

# %% [markdown]
# ## Calculating summary statistics
#
# In the next section of this workshop, we will discuss data cleaning for a more meaningful analysis of our datasets; however, we can already extract some interesting insights from the `meteorites` data by calculating summary statistics.

# %% [markdown]
# #### How many of the meteorites were found versus observed falling?

# %%
taxi.fall.value_counts()

# %% [markdown]
# [The Meteoritical Society states](https://www.lpi.usra.edu/meteor/metbull.php?code=56147) that "relict meteorites are composed mostly of terrestrial minerals, but are thought to have once been meteorites." What proportion of the data are relict meteorites? Let's verify these were all found versus observed falling:

# %%
taxi.value_counts(subset=['nametype', 'fall'], normalize=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1171063508.py in <cell line: 0>()
# ----> 1 taxi.value_counts(subset=['nametype', 'fall'], normalize=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in value_counts(self, subset, normalize, sort, ascending, dropna)
#    7507
#    7508         name = "proportion" if normalize else "count"
# -> 7509         counts = self.groupby(subset, dropna=dropna, observed=False)._grouper.size()
#    7510         counts.name = name
#    7511
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# ...

# %% [markdown]
# #### What was the mass of the average meterorite?

# %%
taxi['mass (g)'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mass (g)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4204827629.py in <cell line: 0>()
# ----> 1 taxi['mass (g)'].mean()
#
# ...

# %% [markdown]
# **Important**: The mean isn't always the best measure of central tendency. If there are outliers in the distribution, the mean will be skewed. Here, the mean is being pulled higher by some very heavy meteorites &ndash; the distribution is [right-skewed](https://www.analyticsvidhya.com/blog/2020/07/what-is-skewness-statistics/).

# %% [markdown]
# Taking a look at some quantiles at the extremes of the distribution shows that the mean is between the 95th and 99th percentile of the distribution, so it isn't a good measure of central tendency here:

# %%
taxi['mass (g)'].quantile([0.01, 0.05, 0.5, 0.95, 0.99])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mass (g)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2558653442.py in <cell line: 0>()
# ----> 1 taxi['mass (g)'].quantile([0.01, 0.05, 0.5, 0.95, 0.99])
#
# ...

# %% [markdown]
# A better measure in this case is the median (50th percentile), since it is robust to outliers:

# %%
taxi.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-765134424.py in <cell line: 0>()
# ----> 1 taxi.median()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11704         **kwargs,
#   11705     ):
# > 11706         result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707         if isinstance(result, Series):
#   11708             result = result.__finalize__(self, method="median")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %% [markdown]
# #### What was the mass of the heaviest meteorite?

# %%
taxi.max()
# Out:
# vendorid                                       2
# tpep_pickup_datetime     2019-10-24T08:19:11.000
# tpep_dropoff_datetime    2019-10-24T17:15:47.000
# passenger_count                                6
# trip_distance                              38.11
# ratecodeid                                     5
# store_and_fwd_flag                             Y
# pulocationid                                 265
# dolocationid                                 265
# payment_type                                   4
# fare_amount                                176.0
# extra                                        7.0
# mta_tax                                      0.5
# tip_amount                                  43.0
# tolls_amount                               612.0
# improvement_surcharge                        0.3
# total_amount                               671.8
# congestion_surcharge                        2.75
# dtype: object

# %% [markdown]
# Let's extract the information on this meteorite:

# %%
taxi.loc[taxi.idxmax()]
# Out:
#       vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0            2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 9355         1  2019-10-24T08:19:11.000  2019-10-24T09:00:35.000
# 9183         2  2019-10-23T17:19:31.000  2019-10-24T17:15:47.000
# 41           2  2019-10-23T16:12:20.000  2019-10-23T16:38:36.000
# 8338         2  2019-10-23T16:50:53.000  2019-10-24T15:32:55.000
# 139          2  2019-10-23T16:45:08.000  2019-10-23T17:45:07.000
# 59           1  2019-10-23T16:21:05.000  2019-10-23T16:53:39.000
# 7192         1  2019-10-23T16:27:45.000  2019-10-23T16:27:58.000
# 255          2  2019-10-23T16:19:26.000  2019-10-23T16:38:59.000
# 1087         2  2019-10-23T16:54:00.000  2019-10-23T17:00:06.000
# 8338         2  2019-10-23T16:50:53.000  2019-10-24T15:32:55.000
# 10           1  2019-10-23T16:35:02.000  2019-10-23T17:57:38.000
# 0            2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# ...

# %% [markdown]
# #### How many different types of meteorite classes are represented in this dataset?

# %%
taxi.nunique()
# Out:
# vendorid                    2
# tpep_pickup_datetime     4281
# tpep_dropoff_datetime    5079
# passenger_count             7
# trip_distance            1243
# ratecodeid                  5
# store_and_fwd_flag          2
# pulocationid              129
# dolocationid              183
# payment_type                4
# fare_amount               199
# extra                      12
# mta_tax                     3
# tip_amount                657
# tolls_amount               37
# improvement_surcharge       3
# total_amount             1097
# congestion_surcharge        4
# dtype: int64

# %% [markdown]
# Some examples:

# %%
taxi.[:14]
# Out:
#   File "/tmp/ipython-input-121599970.py", line 1
#     taxi.[:14]
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# *Note: All fields preceded with "rec" are the values recommended by The Meteoritical Society. Check out [this Wikipedia article](https://en.wikipedia.org/wiki/Meteorite_classification) for some information on meteorite classes.*

# %% [markdown]
# #### Get some summary statistics on the data itself
# We can get common summary statistics for all columns at once. By default, this will only be numeric columns, but here, we will summarize everything together:

# %%
taxi.describe(include='all')
# Out:
#             vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# count   10000.000000                    10000                    10000
# unique           NaN                     4281                     5079
# top              NaN  2019-10-23T16:22:41.000  2019-10-23T16:24:22.000
# freq             NaN                       10                       10
# mean        1.633700                      NaN                      NaN
# std         0.481817                      NaN                      NaN
# min         1.000000                      NaN                      NaN
# 25%         1.000000                      NaN                      NaN
# 50%         2.000000                      NaN                      NaN
# 75%         2.000000                      NaN                      NaN
# max         2.000000                      NaN                      NaN
#
#         passenger_count  trip_distance    ratecodeid store_and_fwd_flag  \
# ...

# %% [markdown]
# **Important**: `NaN` values signify missing data. For instance, the `fall` column contains strings, so there is no value for `mean`; likewise, `mass (g)` is numeric, so we don't have entries for the categorical summary statistics (`unique`, `top`, `freq`).

# %% [markdown]
# #### Check out the documentation for more descriptive statistics:
#
# - [Series](https://pandas.pydata.org/docs/reference/series.html#computations-descriptive-stats)
# - [DataFrame](https://pandas.pydata.org/docs/reference/frame.html#computations-descriptive-stats)

# %% [markdown]
# # Exercises

# %% [markdown]
# Own analysis:

# %%
# Exercise 1.1 Create a DataFrame by reading in the 2019_Yellow_Taxi_Trip_Data.csv file. Examine the first 5 rows.

# %%
# Read the CSV file
taxi = pd.read_csv('/content/2019_Yellow_Taxi_Trip_Data (2).csv')

# View first 5 rows
taxi.head()
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5    1.0      0.5
# ...

# %% [markdown]
# Analysis: file using pandas and displayed the first five rows using the head() function. This allowed me to confirm that the dataset loaded correctly and that the column names (such as trip_distance, fare_amount, tip_amount, tolls_amount, and total_amount) were properly formatted. Viewing the first few rows also helped me understand the structure of the data and the type of information included in each column (for example, pickup and drop-off details, passenger count, and payment information). upon using the taxi.head() you can see the 5 rows here, if you tried to run this part, you can easily notice that date of the pichup time and dropoff time. You can able to put the content at parenthesis and write taxi = pd.read_csv so it will help you to run this code. this while will help you run your code and inside the table you can see those data. Every rows shows the different types of date and distance time and the fare here is also different it depends on the distance every trip.

# %%
# Exercise 1.2 Find the dimensions (number of rows and number of columns) in the data.
print("Number of rows:", taxi.shape[0])
print("Number of columns:", taxi.shape[1])
# Out:
# Number of rows: 10000
# Number of columns: 18

# %% [markdown]
# Analysis: As we run this code, the number of rows shows a number of 10000 while the number of columns is only 18 as we checked the data here. it shows the speific numbers of rows and columns. upon using the word print together with the parenthesis. and returns (columns, rows). I used the shape attribute to determine the dimensions of the dataset. This showed the total number of rows (which represent individual taxi trips) and the total number of columns (which represent the different variables recorded for each trip). Knowing the dataset’s size helps in understanding how large the data is and how much information is available for analysis.

# %%
# Exercise 1.3 Using the data in the 2019_Yellow_Taxi_Trip_Data.csv file, calculate summary statistics for the fare_amount, tip_amount, tolls_amount, and total_amount columns.

# %%
taxi[['fare_amount', 'tip_amount', 'tolls_amount', 'total_amount']].describe()
# Out:
#         fare_amount    tip_amount  tolls_amount  total_amount
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean      15.106313      2.634494      0.623447     22.564659
# std       13.954762      3.409800      6.437507     19.209255
# min      -52.000000      0.000000     -6.120000    -65.920000
# 25%        7.000000      0.000000      0.000000     12.375000
# 50%       10.000000      2.000000      0.000000     16.300000
# 75%       16.000000      3.250000      0.000000     22.880000
# max      176.000000     43.000000    612.000000    671.800000

# %% [markdown]
# Analysis: I calculated summary statistics for the fare_amount, tip_amount, tolls_amount, and total_amount columns using the describe() function. This provided useful statistics such as the mean (average value), minimum and maximum values (to check for possible outliers), and quartiles (to understand how the data is distributed). From this summary, I could observe the general range of fares and tips, and also check if there were any unusual values (such as negative fares or extremely high totals, which might indicate data entry errors). When I started to run this part it helps me noticed those data and I can able to compare it.

# %%
# Exercise 1.4 Isolate the fare_amount, tip_amount, tolls_amount, and total_amount for the longest trip by distance (trip_distance).

# %%
taxi.loc[taxi['trip_distance'].idxmax(),
         ['fare_amount', 'tip_amount', 'tolls_amount', 'total_amount']]
# Out:
# fare_amount      176.0
# tip_amount       18.29
# tolls_amount      6.12
# total_amount    201.21
# Name: 8338, dtype: object

# %% [markdown]
# Analysis: I identified the longest trip by finding the maximum value in the trip_distance column and then isolated the corresponding fare, tip, tolls, and total amount for that trip. This helped me see how the cost of the trip relates to the distance traveled (since longer trips usually result in higher fares). It also allowed me to check whether toll charges were included and whether the tip amount was proportional to the fare.
